# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("E:\\Features_Dataset\\Battery_1_Features.csv")

# %%
df
# Out:
#       Cycle_Index  Skew_Coeff_CV  Kurtosis_Coeff_CV  Mean_Volt   Area_CV  \
# 0             1.0       1.681347           2.195484   0.834296  0.051494
# 1             2.0       1.819808           2.713115   0.831761  0.047155
# 2             3.0       2.020199           3.855508   0.828983  0.045739
# 3             4.0       2.164157           4.580242   0.829497  0.046404
# 4             5.0       2.006209           3.682115   0.829671  0.045231
# ...           ...            ...                ...        ...       ...
# 1173       1185.0       2.147529           4.175437   0.823533  0.027972
# 1174       1186.0       2.278121           5.108263   0.821324  0.028338
# 1175       1187.0       2.519156           6.203738   0.820443  0.028137
# 1176       1188.0       2.753881           7.751375   0.818296  0.028635
# 1177       1189.0       2.289058           4.906479   0.821233  0.027803
#
#             A_CV      t_CV          T_CV  Skew_Coeff_CC  Kurtosis_Coeff_CC  \
# ...

# %% [markdown]
# ## Correlation Matrix

# %%
f, ax1 = plt.subplots(figsize=(24,20))

# comparing correlation between dataset
# Entire DataFrame
corr = df.corr()
sns.heatmap(corr, cmap='coolwarm_r', annot_kws={'size':20}, ax=ax1)
ax1.set_title("Correlation Matrix", fontsize=14)

# Save the plot
plt.savefig('correlation_matrix.jpg', dpi=300, bbox_inches='tight')

# %%
corr = df.corr()
corr[['Nominal_Capacity']]
corr[corr.Nominal_Capacity<-0.7]['Nominal_Capacity']
# Out:
# Cycle_Index   -0.946498
# Entropy_CC    -0.848352
# Name: Nominal_Capacity, dtype: float64

# %%
corr = df.corr()
corr[['Nominal_Capacity']]
corr[corr.Nominal_Capacity>0.7]['Nominal_Capacity']
# Out:
# A_CC                      0.728976
# Cum_Discharge_Capacity    0.752274
# Cum_Discharge_Energy      0.765067
# Frechet_Distance_CV       0.960486
# Shannon_Entropy_CC        0.965438
# Nominal_Capacity          1.000000
# Name: Nominal_Capacity, dtype: float64
