# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("E:\\GaN_Training_Data\\GAN_Battery_1_Features.csv")

# %%
df
# Out:
#       Cycle_Index  Skew_Coeff_CV  Kurtosis_Coeff_CV  Mean_Volt   Area_CV  \
# 0               1       2.668333           7.749297   0.819966  0.029111
# 1               2       2.672771           8.536507   0.817907  0.034438
# 2               3       2.708728           4.012738   0.819508  0.036095
# 3               4       2.521683           6.672646   0.819207  0.031129
# 4               5       2.952595           6.826868   0.824664  0.033882
# ...           ...            ...                ...        ...       ...
# 1173         1174       2.771355           4.650779   0.823062  0.029237
# 1174         1175       2.919750           4.944170   0.818209  0.029356
# 1175         1176       2.478526           5.279446   0.817807  0.033761
# 1176         1177       2.482997           5.750583   0.823002  0.032247
# 1177         1178       2.794201           5.055823   0.823235  0.032494
#
#            A_CV        t_CV         T_CV  Skew_Coeff_CC  Kurtosis_Coeff_CC  \
# 0     86.904286  662.156303  20007.70969       1.457232           0.611873
# 1     82.324373  700.029311  20377.77856       1.603890           1.438570
# 2     81.110593  650.023404  18736.04684       1.273690           1.235817
# 3     85.180524  734.684229  17696.11006       1.169944           0.167929
# 4     87.921034  647.095390  17556.46756       1.329977           0.589193
# ...         ...         ...          ...            ...                ...
# 1173  82.081819  630.023708  19354.37178       1.394188           0.921456
# 1174  80.986675  717.699544  19693.13320       1.565678           0.799277
# 1175  83.745395  640.223856  20835.43451       1.110510           1.367380
# 1176  79.307539  735.289187  17926.71596       1.523440           1.361818
# 1177  87.451758  694.757714  18125.76863       1.185549           0.150185
#
#       ...  Energy_CC  Energy_CV  Energy_Ratio  Energy_Diff  t_CC + t_CV  \
# 0     ...   0.750991   0.027850      0.013544     0.759848  1171.755306
# 1     ...   0.790364   0.032292      0.024467     0.610668  1111.121654
# 2     ...   0.728926   0.027849      0.015471     0.553076  1202.249396
# 3     ...   0.714842   0.032441      0.020558     0.645848  1178.931674
# 4     ...   0.710775   0.030262      0.022559     0.660244  1119.886651
# ...   ...        ...        ...           ...          ...          ...
# 1173  ...   0.741023   0.029316      0.019344     0.588610  1192.036208
# 1174  ...   0.657978   0.026954      0.014623     0.592074  1153.659726
# 1175  ...   0.708957   0.034350      0.015243     0.577637  1224.545137
# 1176  ...   0.685503   0.036373      0.020366     0.542127  1115.633653
# 1177  ...   0.790129   0.031344      0.023533     0.617861  1185.169992
#
#       ratio_CC  T_area/A_ch  T_cc/A_cc   T_cv/A_cv  Nominal_Capacity
# 0     0.452407   -16.059554  28.145987  293.392010          1.069270
# 1     0.387230    15.730760  29.903844  284.204588          1.071042
# 2     0.375269    75.297125  28.330471  291.570393          1.071674
# 3     0.454448    15.194318  29.131885  265.249665          1.072304
# 4     0.415087   -11.852114  28.260581  279.270800          1.072970
# ...        ...          ...        ...         ...               ...
# 1173  0.460324    63.048088  28.193074  246.817236          1.026296
# 1174  0.448559   -51.134025  27.819423  283.908137          1.026559
# 1175  0.431196     0.003195  27.896688  256.759410          1.026315
# 1176  0.472155    49.028237  28.796604  267.266551          1.026620
# 1177  0.467572    20.543977  27.941179  270.165227          1.026054
#
# [1178 rows x 51 columns]

# %% [markdown]
# ## Correlation Matrix

# %%
f, ax1 = plt.subplots(figsize=(24,20))

# comparing correlation between dataset
# Entire DataFrame
corr = df.corr()
sns.heatmap(corr, cmap='coolwarm_r', annot_kws={'size':20}, ax=ax1)
ax1.set_title("Correlation Matrix", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
corr = df.corr()
corr[['Nominal_Capacity']]
corr[corr.Nominal_Capacity<-0.7]['Nominal_Capacity']
# Out:
# Cycle_Index   -0.946545
# Name: Nominal_Capacity, dtype: float64

# %%
corr = df.corr()
corr[['Nominal_Capacity']]
corr[corr.Nominal_Capacity>0.7]['Nominal_Capacity']
# Out:
# Nominal_Capacity    1.0
# Name: Nominal_Capacity, dtype: float64
